# %% [markdown]
# ## Newton Raphson Method
# <hr/>
# <b>By Ivan Septian. <br/> NIM 2008157 <br/> KOM5A </b>

# %%
# No. 1 f(x) = x^3 - 2x + 1            

# Definisikan f(x)
def f(x):
    # x^3 - 2x + 1     
    hasil = x**3 - 2*x + 1
    return hasil

# Definisikan turunan dari f(x) 
def dfdx(x):
    hasil = 3*x**2 - 2
    return hasil

# Definisikan fungsi untuk metode Newton-Raphson
def newtonRaphson(x0, e, N):
    # Iterasi counter, diawali dengan nilai 0
    i = 0
    
    # Variabel boolean untuk menentukan apakah akar ditemukan atau tidak, diawali dengan nilai 1 (ditemukan) 
    # dan akan berubah apabila ada kondisi yang membuat suatu akar tidak ditemukan
    ditemukan = 1
    
    # Variabel untuk menghandle division by zero, diawali dengan nilai 0 (belum ada division by zero)
    divisionByZero = 0
    
    # Definisikan xi_1 (hasil) dengan nilai x0 (apabila x0 merupakan akar persamaan)    
    xi_1 = x0
    
    while abs(f(xi_1)) > e:
        # Iterasi bertambah setiap perulangan terjadi
        i = i + 1
        
        # Kondisi untuk akar tidak ditemukan (jumlah perulangan (nilai i) melebihi maksimum iterasi yang ditentukan (N))
        if i > N:
            ditemukan = 0
            break
        
        # Apabila turunan f(x) bernilai 0, maka perulangan berhenti dengan "Division by zero error"
        if dfdx(xi_1) == 0.0:
            divisionByZero = 1
            break
        
        # xi (tebakan selanjutnya) didapat dengan rumus = xi_1 (tebakan sebelumnya) - (f(xi_1)/turunan f(xi_1))
        xi = xi_1 - f(xi_1) / dfdx(xi_1)
        print("Iterasi ke-" + str(i) + ": x = " + str(xi) + ", f(x) = " + str(f(xi)) + ", Turunan f(x) = " + str(dfdx(xi)))
        
        # Hasil (xi_1) merupakan tebakan terakhir yang ditemukan dalam perulangan (xi)
        xi_1 = xi
    
    # Kondisi jika akar ditemukan, division by zero, atau akar tidak ditemukan
    if ditemukan == 1 and divisionByZero == 0:
        print('\nAkar persamaan (solusi) adalah %f' % xi_1)
    elif divisionByZero == 1:
         print('\nDivision by zero!\nAkar tidak ditemukan!')
    else:
        print('\nAkar tidak ditemukan!')
             
    
# Jalankan fungsi metode Newton-Raphon
# Input x0 (tebakan awal), e (toleransi galat), dan N (maksimum iterasi)
x0 = input("Masukan Tebakan Pertama: ")
e = input("Toleransi galat (e): ")
N = input("Maksimum iterasi (N): ")

# Konversi nilai x0 da e menjadi float
x0 = float(x0)
e = float(e)

# Konversi nilai N menjadi integer
N = int(N)

# Fungsi Newton-Raphson Dijalankan
newtonRaphson(x0, e, N)
# Out:
# Masukan Tebakan Pertama: 3
# Toleransi galat (e): 0.001
# Maksimum iterasi (N): 100
# Iterasi ke-1: x = 2.12, f(x) = 6.288128, Turunan f(x) = 11.483200000000002
# Iterasi ke-2: x = 1.5724062978960571, f(x) = 1.742901541362622, Turunan f(x) = 5.417384696989552
# Iterasi ke-3: x = 1.2506825070175627, f(x) = 0.4549609847369811, Turunan f(x) = 2.692620200079207
# Iterasi ke-4: x = 1.0817166110016307, f(x) = 0.1022950957528661, Turunan f(x) = 1.5103324795505602
# Iterasi ke-5: x = 1.0139864276559698, f(x) = 0.014576024158892809, Turunan f(x) = 1.0845054264115461
# Iterasi ke-6: x = 1.0005461775623188, f(x) = 0.000547072655037617, Turunan f(x) = 1.0032779603037016
#
# Akar persamaan (solusi) adalah 1.000546

# %%
# No. 2 f(x) = e^x - x

# Import library math untuk fungsi eksponensial
import math

# Definisikan f(x)
def f(x):
    # e^x - x   
    hasil = math.exp(x) - x
    return hasil

# Definisikan turunan dari f(x) 
def dfdx(x):
    hasil = math.exp(x) - 1
    return hasil

# Definisikan fungsi untuk metode Newton-Raphson
def newtonRaphson(x0, e, N):
    # Iterasi counter, diawali dengan nilai 0
    i = 0
    
    # Variabel boolean untuk menentukan apakah akar ditemukan atau tidak, diawali dengan nilai 1 (ditemukan) 
    # dan akan berubah apabila ada kondisi yang membuat suatu akar tidak ditemukan
    ditemukan = 1
    
    # Variabel untuk menghandle division by zero, diawali dengan nilai 0 (belum ada division by zero)
    divisionByZero = 0
    
    # Definisikan xi_1 (hasil) dengan nilai x0 (apabila x0 merupakan akar persamaan)    
    xi_1 = x0
    
    while abs(f(xi_1)) > e:
        # Iterasi bertambah setiap perulangan terjadi
        i = i + 1
        
        # Kondisi untuk akar tidak ditemukan (jumlah perulangan (nilai i) melebihi maksimum iterasi yang ditentukan (N))
        if i > N:
            ditemukan = 0
            break
        
        # Apabila turunan f(x) bernilai 0, maka perulangan berhenti dengan "Division by zero error"
        if dfdx(xi_1) == 0.0:
            divisionByZero = 1
            break
        
        # xi (tebakan selanjutnya) didapat dengan rumus = xi_1 (tebakan sebelumnya) - (f(xi_1)/turunan f(xi_1))
        xi = xi_1 - f(xi_1) / dfdx(xi_1)
        print("Iterasi ke-" + str(i) + ": x = " + str(xi) + ", f(x) = " + str(f(xi)) + ", Turunan f(x) = " + str(dfdx(xi)))
        
        # Hasil (xi_1) merupakan tebakan terakhir yang ditemukan dalam perulangan (xi)
        xi_1 = xi
    
    # Kondisi jika akar ditemukan, division by zero, atau akar tidak ditemukan
    if ditemukan == 1 and divisionByZero == 0:
        print('\nAkar persamaan (solusi) adalah %f' % xi_1)
    elif divisionByZero == 1:
         print('\nDivision by zero!\nAkar tidak ditemukan!')
    else:
        print('\nAkar tidak ditemukan!')
             
    
# Jalankan fungsi metode Newton-Raphson
# Input x0 (tebakan awal), e (toleransi galat), dan N (maksimum iterasi)
x0 = input("Masukan Tebakan Pertama: ")
e = input("Toleransi galat (e): ")
N = input("Maksimum iterasi (N): ")

# Konversi nilai x0 da e menjadi float
x0 = float(x0)
e = float(e)

# Konversi nilai N menjadi integer
N = int(N)

# Fungsi Newton-Raphson Dijalankan
newtonRaphson(x0, e, N)
# Out:
# Masukan Tebakan Pertama: 5
# Toleransi galat (e): 0.001
# Maksimum iterasi (N): 100
# Iterasi ke-1: x = 4.027134619625217, f(x) = 52.072798458532084, Turunan f(x) = 55.0999330781573
# Iterasi ke-2: x = 3.0820736086677507, f(x) = 18.72149401064991, Turunan f(x) = 20.80356761931766
# Iterasi ke-3: x = 2.182156135221244, f(x) = 6.683244533669762, Turunan f(x) = 7.865400668891006
# Iterasi ke-4: x = 1.3324544079967011, f(x) = 2.457880600748576, Turunan f(x) = 2.790335008745277
# Iterasi ke-5: x = 0.4515993877051394, f(x) = 1.1192231439856164, Turunan f(x) = 0.5708225316907558
# Iterasi ke-6: x = -1.5091205941612345, f(x) = 1.7302249270909942, Turunan f(x) = -0.7788956670702403
# Iterasi ke-7: x = 0.712261550124033, f(x) = 1.326334887164349, Turunan f(x) = 1.038596437288382
# Iterasi ke-8: x = -0.564783931205759, f(x) = 1.1332668961230121, Turunan f(x) = -0.43151703508274697
# Iterasi ke-9: x = 2.0614551369823575, f(x) = 5.79593994482107, Turunan f(x) = 6.8573950818034275
# ...
